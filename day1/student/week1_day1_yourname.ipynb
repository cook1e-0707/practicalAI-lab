# %% [markdown]
# <a href="https://colab.research.google.com/github/cook1e-0707/practicalAI-lab/blob/main/day1/student/week1_day1_yourname.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/>
# </a>
#
# # Week 1 · Day 1 Student Lab
# ## Python, Data, and the Lemonade Sales Challenge
#
# **Before you start:** Choose **File → Save a copy in Drive**. Rename it
# `week1_day1_yourname.ipynb`.

# %% [markdown]
# ## How to use this notebook
#
# - Run a code cell with ▶ or **Shift+Enter**.
# - Replace `None` or a `# TODO` comment with your code.
# - A task may show an error until your answer is correct.
# - Read the error message first.
# - Open Hint 1, then Hint 2, only when needed.
#
# You are not expected to memorize every function name. Your goal is to
# understand what each step does.

# %%
# Run this setup cell once.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

print("Setup complete!")

# %% [markdown]
# # Part 1 — Python warm-up
#
# This section assumes you have never programmed before. Complete it in
# order because later cells use ideas from earlier cells.
#
# ## Task 1A: Read and modify code
#
# A code cell runs from top to bottom. Text goes inside quotes.
# `print(...)` shows a result. A line beginning with `#` is a comment and
# is not executed.
#
# Before running the cell:
#
# 1. Predict the two output lines.
# 2. Run it.
# 3. Change the name and number.
# 4. Run it again.

# %%
# This comment is for humans.
print("Hello, my name is Alex.")
print("I predict", 50, "cups will be sold.")

# %%
# TODO: Store the number of output lines.
number_of_output_lines = None

assert number_of_output_lines == 2, "Count the print(...) instructions."
print("Task 1A complete!")

# %% [markdown]
# <details>
# <summary>What to notice</summary>
#
# - Parentheses contain the information given to `print`.
# - Commas let one `print` instruction show text and numbers together.
# - Python is case-sensitive: use lowercase `print`, not `Print`.
# </details>

# %% [markdown]
# ## Task 1B: Values, types, and variables
#
# A **value** is one piece of information. A **variable** gives a value a
# useful name. The assignment operator `=` stores the value on the right
# under the name on the left.
#
# | Type | Example | Meaning |
# |---|---|---|
# | `int` | `12` | whole number |
# | `float` | `2.5` | decimal number |
# | `str` | `"Blue"` | text |
# | `bool` | `True` | true or false |
#
# Create:
#
# - a string variable named `student_name`;
# - a number variable named `predicted_cups`;
# - a Boolean variable named `is_weekend`.

# %%
# TODO: Replace each None with your own value.
student_name = None
predicted_cups = None
is_weekend = None

print(student_name, predicted_cups, is_weekend)

# %%
# Run this check after completing the previous cell.
assert isinstance(student_name, str), "student_name should be text in quotes."
assert isinstance(predicted_cups, (int, float)), "Use a number."
assert isinstance(is_weekend, bool), "Use True or False."
print("Task 1B complete!")

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Text goes inside quotes. A Boolean is written as `True` or `False`
# without quotes.
# </details>
#
# <details>
# <summary>Hint 2: code shape</summary>
#
# ```python
# student_name = "..."
# predicted_cups = 0
# is_weekend = False
# ```
# Change the example values to your own.
# </details>

# %% [markdown]
# ## Task 1C: Arithmetic and updating a variable
#
# Python uses `+`, `-`, `*`, and `/` for arithmetic. Parentheses control
# the order of operations.
#
# Trace the value of `cups_sold`:
#
# - it starts at 10;
# - 3 more cups are sold;
# - 1 order is refunded.
#
# Complete the two update lines.

# %%
cups_sold = 10
cups_sold = None   # TODO: old cups_sold plus 3
cups_sold = None   # TODO: current cups_sold minus 1

number_of_cups = 12
price_per_cup = 2.5
revenue = None     # TODO: multiply cups by price

print("Final cups:", cups_sold)
print("Revenue: $", revenue)

# %%
assert cups_sold == 12, "Update using cups_sold + 3, then cups_sold - 1."
assert revenue == 30.0, "Revenue is number_of_cups * price_per_cup."
print("Task 1C complete!")

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# The right side is calculated first. Then `=` stores the new result.
# A variable may appear on both sides: `score = score + 1`.
# </details>
#
# <details>
# <summary>Hint 2: operators</summary>
#
# Use `+`, then `-`, then `*` in the three TODOs.
# </details>

# %% [markdown]
# ## Task 1D: Strings and type conversion
#
# `"12"` is text; `12` is a number. Python cannot add text and a number
# directly. `int(...)` converts suitable text to an integer.
#
# Complete the conversion and make an f-string message.

# %%
cups_text = "12"
extra_cups = 3

cups_number = None   # TODO: convert cups_text with int(...)
total_cups = None    # TODO: add cups_number and extra_cups
message = None       # TODO: f"Total cups: {total_cups}"

print(message)
print(type(total_cups))

# %%
assert cups_number == 12 and isinstance(cups_number, int)
assert total_cups == 15
assert message == "Total cups: 15"
print("Task 1D complete!")

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Conversion looks like `new_value = int(old_value)`.
# </details>
#
# <details>
# <summary>Hint 2: f-string shape</summary>
#
# Put `f` before the opening quote and put a variable in braces:
# `f"Some text {variable_name}"`.
# </details>
#
# ### When an error appears
#
# Read the last line first:
#
# - `NameError`: a name may be misspelled or its cell was not run;
# - `TypeError`: an operation received the wrong kind of value;
# - `SyntaxError`: check quotes, parentheses, colons, and indentation;
# - `IndexError`: the requested list position does not exist.

# %% [markdown]
# ## Task 2A: Lists, length, and indexes
#
# The first item in a Python list has index `0`.
#
# 1. Print the first temperature.
# 2. Print the last temperature using index `-1`.
# 3. Count the values with `len(...)`.

# %%
temperatures = [68, 72, 81, 75]

first_temperature = None   # TODO
last_temperature = None    # TODO: use -1
number_of_temperatures = None

print(first_temperature)
print(last_temperature)
print(number_of_temperatures)

# %%
assert first_temperature == temperatures[0], "Remember: the first index is 0."
assert last_temperature == temperatures[-1], "Use index -1 for the last item."
assert number_of_temperatures == 4, "Use len(temperatures)."
print("Task 2A complete!")

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Select a list item with `list_name[index]`.
# </details>

# %% [markdown]
# ## Task 2B: Change, add, and slice list items
#
# Lists can change after they are created:
#
# - `values[index] = new_value` replaces one item;
# - `values.append(new_value)` adds an item;
# - `values[start:stop]` selects a slice and stops before `stop`.

# %%
temperatures = [68, 72, 81, 75]

# TODO 1: replace the first value with 70

# TODO 2: append 79

first_three = None   # TODO 3: slice indexes 0 through 2

print(temperatures)
print(first_three)

# %%
assert temperatures == [70, 72, 81, 75, 79]
assert first_three == [70, 72, 81]
print("Task 2B complete!")

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Replace with `temperatures[0] = ...`. Add with
# `temperatures.append(...)`.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# A slice of the first three values is `temperatures[0:3]`.
# </details>

# %% [markdown]
# ## Task 3A: Comparisons and Booleans
#
# Comparisons create `True` or `False`:
#
# | Meaning | Operator |
# |---|---|
# | equal | `==` |
# | not equal | `!=` |
# | greater/less | `>` / `<` |
# | at least/at most | `>=` / `<=` |
#
# Complete two Boolean expressions.

# %%
temperature = 84
is_weekend = True

hot_day = None             # TODO: temperature is at least 80
busy_day = None            # TODO: hot_day AND is_weekend

print("Hot day?", hot_day)
print("Busy day?", busy_day)

# %%
assert hot_day is True
assert busy_day is True
print("Task 3A complete!")

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Use `temperature >= 80`. Combine two Boolean values with `and`.
# Remember: `=` stores a value, while `==` compares two values.
# </details>

# %% [markdown]
# ## Task 3B: Decisions with `if`, `elif`, and `else`
#
# Complete the first condition:
#
# - at least 90°F → `"very hot"`;
# - otherwise at least 80°F → `"hot"`;
# - anything else → `"mild"`.
#
# Notice the colon and four-space indentation.

# %%
temperature = 84
very_hot = False             # TODO: replace False with a comparison

if very_hot:
    plan = "very hot"
elif temperature >= 80:
    plan = "hot"
else:
    plan = "mild"

print(plan)

# %%
assert very_hot == (temperature >= 90), "Compare temperature with 90."
assert plan == "hot", "At 84°F, the second branch should run."
print("Task 3B complete!")

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# The first branch is for “at least 90.”
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# Replace the `False` assigned to `very_hot` with `temperature >= 90`.
# </details>

# %% [markdown]
# ## Task 4A: A loop and an accumulator
#
# A `for` loop visits each value in a list. An accumulator keeps a running
# result.
#
# Complete the indented update so `total_cups` becomes the sum of all
# three days.

# %%
daily_sales = [10, 12, 8]
total_cups = 0

for sales in daily_sales:
    total_cups = None   # TODO: old total_cups plus sales
    print("Running total:", total_cups)

print("Final total:", total_cups)

# %%
assert total_cups == 30
print("Task 4A complete!")

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Use `total_cups = total_cups + sales` inside the loop.
# </details>

# %% [markdown]
# ## Task 4B: Define and call a function
#
# A function packages steps that can be reused:
#
# - `def` starts the definition;
# - parameters are input names;
# - the indented body does the work;
# - `return` sends a result back;
# - writing the definition does not run it—you must call the function.
#
# Complete the returned calculation, then call the function.

# %%
def total_price(number_of_cups, price_per_cup):
    return None   # TODO: multiply the two parameters

price_for_three = None   # TODO: call total_price with 3 and 2.0

print("Three cups cost $", price_for_three)

# %%
assert total_price(3, 2.0) == 6.0
assert price_for_three == 6.0
print("Task 4B complete!")

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Inside the function, multiply `number_of_cups * price_per_cup`.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# A function call looks like
# `result = function_name(first_input, second_input)`.
# </details>
#
# ### Python self-check
#
# Explain these in your own words before continuing:
#
# 1. What is the difference between `=` and `==`?
# 2. Why are `"12"` and `12` different?
# 3. What does index `-1` select?
# 4. What does indentation show Python?
# 5. What is the difference between defining and calling a function?

# %% [markdown]
# ## Python quick reference
#
# You may copy these **shapes** and replace the names and values:
#
# ```python
# # Store and print
# temperature = 84
# print(temperature)
#
# # Calculate
# revenue = number_of_cups * price_per_cup
#
# # Convert text to a number
# cups = int("12")
#
# # Create and select from a list
# values = [10, 12, 8]
# first = values[0]
# last = values[-1]
#
# # Decide
# if temperature >= 80:
#     message = "hot"
# else:
#     message = "mild"
#
# # Repeat
# for value in values:
#     print(value)
#
# # Define, return, and call
# def double(number):
#     return number * 2
#
# answer = double(5)
# ```
#
# This is a reference, not a memorization test.

# %% [markdown]
# # Part 2 — NumPy
#
# ## Task 5: Arrays and numerical operations
#
# 1. Turn the list into a NumPy array with `np.array(...)`.
# 2. Calculate the mean with `.mean()`.
# 3. Add 5 to every value without writing a loop.

# %%
sales_list = [40, 55, 62, 48]

sales = None               # TODO: make a NumPy array
average_sales = None       # TODO: calculate its mean
increased_sales = None     # TODO: add 5 to every value

print("Array:", sales)
print("Shape:", sales.shape if isinstance(sales, np.ndarray) else "not an array yet")
print("Average:", average_sales)
print("After +5:", increased_sales)

# %%
assert isinstance(sales, np.ndarray), "Use np.array(sales_list)."
assert average_sales == 51.25, "Use the array's .mean() method."
assert np.array_equal(increased_sales, np.array([45, 60, 67, 53]))
print("Task 5 complete!")

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# NumPy was imported using the short name `np`.
# </details>
#
# <details>
# <summary>Hint 2: function names</summary>
#
# Use `np.array(...)`, then `sales.mean()`, then `sales + ...`.
# </details>

# %% [markdown]
# # Part 3 — Pandas
#
# ## Task 6: Load and inspect a CSV
#
# A CSV file is a table saved as text. Use `pd.read_csv(...)` to load the
# URL into a DataFrame named `data`.

# %%
DATA_URL = (
    "https://raw.githubusercontent.com/cook1e-0707/"
    "practicalAI-lab/main/day1/data/lemonade_sales.csv"
)

# TODO: replace None with code that reads the CSV.
data = None

# %%
assert isinstance(data, pd.DataFrame), "Use pd.read_csv(DATA_URL)."
assert data.shape == (72, 4), "The table should have 72 rows and 4 columns."
print("Task 6 complete!")
data.head()

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# The function name is `pd.read_csv`.
# </details>
#
# <details>
# <summary>Hint 2: code shape</summary>
#
# ```python
# data = pd.read_csv(...)
# ```
#
# Put the variable containing the URL inside the parentheses.
# </details>

# %% [markdown]
# ## Task 7: Ask questions about the table
#
# Complete the code, then answer:
#
# - How many rows and columns are there?
# - What is the average number of cups sold?
# - Are any values missing?
# - Do rainy days appear to have lower sales?

# %%
print("Rows and columns:", data.shape)
print("\nMissing values by column:")
print(data.isna().sum())

average_cups = None   # TODO: select cups_sold and calculate the mean
rainy_days = None     # TODO: keep rows where rain equals 1

print("\nAverage cups sold:", average_cups)
print("Rainy days:", len(rainy_days) if isinstance(rainy_days, pd.DataFrame) else "TODO")

# %%
assert np.isclose(average_cups, data["cups_sold"].mean())
assert isinstance(rainy_days, pd.DataFrame)
assert (rainy_days["rain"] == 1).all(), "Filter using data['rain'] == 1."
print("Task 7 complete!")

# %%
# Run this chart after task 7.
data.plot.scatter(
    x="temperature_f",
    y="cups_sold",
    c=data["rain"].map({0: "#1976D2", 1: "#E53935"}),
    alpha=0.75,
)
plt.title("Lemonade sales: blue = dry, red = rain")
plt.show()

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Select one column with `data["column_name"]`. Calculate an average with
# `.mean()`.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# Filter rows using `data[data["column_name"] == value]`.
# </details>

# %% [markdown]
# # Part 4 — Lemonade Sales Challenge
#
# **Question:** Can we predict `cups_sold` using weather and day
# information?
#
# ## Task 8: Understand the problem
#
# Think about these questions and edit this Markdown cell:
#
# - Our target is: **...**
# - Possible features are: **...**
# - A column that must not be used as a feature is: **...**
# - We think the most useful feature will be **...** because **...**

# %% [markdown]
# ## Task 9: Protect the final exam
#
# Run the provided split. It makes approximately:
#
# - 60% training data;
# - 20% validation data;
# - 20% test data.
#
# The fixed random seed gives every student the same split.

# %%
train_data, remaining_data = train_test_split(
    data,
    test_size=0.40,
    random_state=42,
)

validation_data, test_data = train_test_split(
    remaining_data,
    test_size=0.50,
    random_state=42,
)

print("Training rows:", len(train_data))
print("Validation rows:", len(validation_data))
print("Test rows:", len(test_data))

# %% [markdown]
# **Before continuing, answer:**
#
# 1. Which set should the model learn from?
# 2. Which set should we use to compare Models A, B, and C?
# 3. Which set should remain untouched until the end?

# %% [markdown]
# ## Task 10: Model A — temperature only
#
# Fill the three TODOs:
#
# 1. create a linear-regression model;
# 2. fit it using training rows;
# 3. predict the validation rows.

# %%
features_A = ["temperature_f"]

model_A = None
# TODO: train model_A using train_data[features_A] and train_data["cups_sold"]

predictions_A = None

# Keep this line: it measures the typical prediction error in cups.
mae_A = mean_absolute_error(
    validation_data["cups_sold"],
    predictions_A,
)
print("Model A validation MAE:", round(mae_A, 2), "cups")

# %%
assert isinstance(model_A, LinearRegression), "Create LinearRegression()."
assert predictions_A is not None, "Use model_A.predict(...)."
assert len(predictions_A) == len(validation_data)
assert 8 < mae_A < 11, "Check that training uses train_data and prediction uses validation_data."
print("Task 10 complete!")

# %% [markdown]
# <details>
# <summary>Hint 1: ideas</summary>
#
# `.fit()` learns from features and targets. `.predict()` needs only
# features.
# </details>
#
# <details>
# <summary>Hint 2: code shape</summary>
#
# ```python
# model_A = LinearRegression()
# model_A.fit(training_features, training_target)
# predictions_A = model_A.predict(validation_features)
# ```
#
# Replace each description with a DataFrame selection.
# </details>

# %% [markdown]
# ## Task 11: Model B — temperature + weekend
#
# Repeat the workflow with two features. Use the same target and the same
# training/validation rows so the comparison is fair.

# %%
features_B = None       # TODO: a list containing two column names
model_B = None          # TODO

# TODO: fit model_B

predictions_B = None    # TODO
mae_B = None            # TODO: calculate validation MAE

print("Model B validation MAE:", round(mae_B, 2) if mae_B is not None else "TODO")

# %%
assert features_B == ["temperature_f", "weekend"], "Use the two requested features."
assert isinstance(model_B, LinearRegression)
assert predictions_B is not None and len(predictions_B) == len(validation_data)
assert np.isclose(
    mae_B,
    mean_absolute_error(validation_data["cups_sold"], predictions_B),
)
print("Task 11 complete!")

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Copy the shape of Model A, but use
# `["temperature_f", "weekend"]`. Then calculate MAE with the validation
# target and your new predictions.
# </details>

# %% [markdown]
# ## Task 12: Model C — your feature choice
#
# Choose one or more available features:
#
# `temperature_f`, `weekend`, `rain`
#
# Make a prediction first:
#
# > We chose ___ because ___.
#
# Then train and validate Model C.

# %%
features_C = None       # TODO: your list of feature names
model_C = None          # TODO

# TODO: fit model_C

predictions_C = None    # TODO
mae_C = None            # TODO

print("Model C features:", features_C)
print("Model C validation MAE:", round(mae_C, 2) if mae_C is not None else "TODO")

# %%
allowed_features = {"temperature_f", "weekend", "rain"}
assert isinstance(features_C, list) and len(features_C) >= 1
assert set(features_C).issubset(allowed_features)
assert isinstance(model_C, LinearRegression)
assert predictions_C is not None and len(predictions_C) == len(validation_data)
assert np.isclose(
    mae_C,
    mean_absolute_error(validation_data["cups_sold"], predictions_C),
)
print("Task 12 complete!")

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Which available feature has not yet been used? Look again at the scatter
# plot and compare blue and red points.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# Copy the Model B workflow. Change only the feature list and variable
# names.
# </details>

# %% [markdown]
# ## Task 13: Choose before testing
#
# Run the comparison table. Then set `chosen_name` to `"A"`, `"B"`, or
# `"C"`.
#
# Do **not** choose based on test results. The test set is still closed.

# %%
validation_results = pd.DataFrame(
    {
        "model": ["A", "B", "C"],
        "features": [features_A, features_B, features_C],
        "validation_MAE": [mae_A, mae_B, mae_C],
    }
).sort_values("validation_MAE")

validation_results

# %%
# TODO: choose using validation MAE, then explain the decision below.
chosen_name = None

model_lookup = {"A": model_A, "B": model_B, "C": model_C}
feature_lookup = {"A": features_A, "B": features_B, "C": features_C}

assert chosen_name in model_lookup, 'Use "A", "B", or "C".'
chosen_model = model_lookup[chosen_name]
chosen_features = feature_lookup[chosen_name]

print("Chosen model:", chosen_name)
print("Chosen features:", chosen_features)

# %% [markdown]
# **Record your decision before opening the test set:**
#
# > We selected Model ___ with features ___. Its validation MAE was ___
# > cups. We selected it because ___.

# %% [markdown]
# ## Final test — run once after recording your choice
#
# Complete the prediction and MAE lines for the chosen model.

# %%
test_predictions = None   # TODO: chosen_model.predict(...)
test_mae = None            # TODO: compare the real test target and predictions

print("Final test MAE:", round(test_mae, 2) if test_mae is not None else "TODO", "cups")

# %%
assert test_predictions is not None
assert len(test_predictions) == len(test_data)
assert np.isclose(
    test_mae,
    mean_absolute_error(test_data["cups_sold"], test_predictions),
)
print("Great job! Your first ML model works!")

# %% [markdown]
# # Reflection
#
# Answer in complete sentences:
#
# 1. Our final test MAE was ___ cups. In everyday language, this means ___.
# 2. Was the test MAE exactly the same as validation MAE? Why might it differ?
# 3. Which feature helped most? What evidence supports your answer?
# 4. What useful information is missing from this dataset?
# 5. Complete: Training data is for ___, validation data is for ___, and
#    test data is for ___.
# 6. Why should we not repeatedly choose models using test results?

# %% [markdown]
# # Optional fast-finisher challenges
#
# Choose one:
#
# - Plot actual test values against predictions.
# - Predict sales for a new day: 80°F, weekend, no rain.
# - Add a new feature you think a real lemonade stand should record.
# - Compare the average `cups_sold` for rainy and dry days.
# - Explain one reason a linear model might fail in the real world.
#
# **Safety question:** Should a model trained only on 55–95°F data be
# trusted at 20°F or 120°F? Why or why not?
